# %% [markdown]
# # Fase 1.4: Compilación desde el Hailo Archive Quantized Model a HEF (Hailo Executable Format)

# %%
# Imports

from hailo_sdk_client import ClientRunner

# %% [markdown]
# ## 1. Compilar el modelo HAR cuantizado a modelo HEF ejecutable

# %%
# Cargamos el modelo HAR cuantizado

optimization_level = 2
compression_level = 0
model_name = "../results/models/model_ResBaGAN_discriminator"
quantized_model_har_path = f"{model_name}_quantized_model_o{optimization_level}_c{compression_level}.har"

# %%
# Cargar el ClientRunner

runner = ClientRunner(har=quantized_model_har_path)
# By default it uses the hw_arch that is saved on the HAR. It is not recommended to change the hw_arch after Optimization.

# %%
# Ejecutar el compilador

hef = runner.compile()

file_name = f"{model_name}_o{optimization_level}_c{compression_level}.hef"
with open(file_name, "wb") as f:
    f.write(hef)
# Out:
# [info] To achieve optimal performance, set the compiler_optimization_level to "max" by adding performance_param(compiler_optimization_level=max) to the model script. Note that this may increase compilation time.
# [info] Loading network parameters
# [info] Starting Hailo allocation and compilation flow
# [info] Building optimization options for network layers...
# [info] Successfully built optimization options - 2s 484ms
# [info] Trying to compile the network in a single context
# [info] Using Single-context flow
# [info] Resources optimization params: max_control_utilization=75%, max_compute_utilization=75%, max_compute_16bit_utilization=75%, max_memory_utilization (weights)=75%, max_input_aligner_utilization=75%, max_apu_utilization=75%
# [info] Validating layers feasibility
# [info] output_layer1: Pass
# [info] output_layer2: Pass
# [info] input_layer1: Pass
# [info] conv5: Pass
# [info] external_pad1: Pass
# [info] conv3: Pass
# [info] conv6: Pass
# [info] conv7: Pass
# [info] conv2: Pass
# [info] conv4: Pass
# [info] conv8: Pass
# [info] ew_add2: Pass
# [info] conv10: Pass
# [info] ew_add1: Pass
# [info] conv1: Pass
# [info] ew_add3: Pass
# [info] conv12_defuse_width_feature_reshape: Pass
# [info] conv12_defuse_reshape_hxf_to_w_transposed: Pass
# [info] conv20_d1: Pass
# [info] external_pad2: Pass
# [info] conv24_dc: Pass
# [info] ew_add9: Pass
# [info] conv20_dc: Pass
# [info] conv11: Pass
# [info] ew_add8: Pass
# [info] conv13: Pass
# [info] conv20_d0: Pass
# [info] ew_add10: Pass
# [info] avgpool1: Pass
# [info] conv22_d1: Pass
# [info] conv9: Pass
# [info] conv24_d0: Pass
# [info] ew_add11: Pass
# [info] conv15: Pass
# [info] ew_add4: Pass
# [info] ew_add5: Pass
# [info] conv24_d1: Pass
# [info] conv14: Pass
# [info] conv22_dc: Pass
# [info] ew_add6: Pass
# [info] conv19: Pass
# [info] fc1: Pass
# [info] ew_add7: Pass
# [info] conv18: Pass
# [info] conv12_defuse_1x1: Pass
# [info] conv17: Pass
# [info] external_pad3: Pass
# [info] conv16: Pass
# [info] conv22_d0: Pass
# [info] conv23: Pass
# [info] conv21: Pass
# [info] Layers feasibility validated successfully
# [info] Running resources allocation (mapping) flow, time per context: 59m 59s
#
#
# [info] Context:0/0 Iteration 0: Mapping prepost...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1
#  worker2
#  worker3
#
#   00:00
# [info] Context:0/0 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1
#  worker2
#  worker3
#
#   00:00
# [info] Context:0/0 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 0: Trying parallel splits...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          *          *          *          *          *          *          *          V
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          V          *          *          *          *          *          *          V
#  worker2  *          *          *          *          *          *          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          V          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          V          *          *          *          *          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          *          *          *          *          *          *          *          V
#  worker1  *          V          *          *          *          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  *          V          *          *          V          *          *          *          V
#  worker1  *          V          *          *          *          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          *          *          *          V
#  worker1  *          V          *          *          *          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          *          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          *          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  *          *          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:00
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  *          *          *          *          *          *          *          *          V
#
#   00:02
# [info] Context:0/0 Iteration 4: Trying parallel mapping...
#           cluster_0  cluster_1  cluster_2  cluster_3  cluster_4  cluster_5  cluster_6  cluster_7  prepost
#  worker0  V          V          *          *          V          V          *          *          V
#  worker1  V          V          *          *          V          V          *          *          V
#  worker2  V          V          *          *          V          V          *          *          V
#  worker3  V          *          *          *          V          V          *          *          V
#
#   00:02
#
# [info] Iterations: 4
# Reverts on cluster mapping: 0
# Reverts on inter-cluster connectivity: 0
# Reverts on pre-mapping validation: 0
# Reverts on split failed: 0
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Cluster   | Control Utilization | Compute Utilization | Memory Utilization |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | cluster_0 | 50%                 | 35,9%               | 23,4%              |
# [info] | cluster_1 | 100%                | 26,6%               | 23,4%              |
# [info] | cluster_4 | 100%                | 53,1%               | 26,6%              |
# [info] | cluster_5 | 50%                 | 59,4%               | 22,7%              |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] | Total     | 75%                 | 43,8%               | 24%                |
# [info] +-----------+---------------------+---------------------+--------------------+
# [info] Successful Mapping (allocation time: 6s)
# [info] Compiling kernels of model_ResBaGAN_discriminator_context_0...
# [info] Bandwidth of model inputs: 0.0390625 Mbps, outputs: 0.00106049 Mbps (for a single frame)
# [info] Bandwidth of DDR buffers: 0.0 Mbps (for a single frame)
# [info] Bandwidth of inter context tensors: 0.0 Mbps (for a single frame)
# [info] Compiling kernels of model_ResBaGAN_discriminator_context_0...
# [info] Bandwidth of model inputs: 0.0390625 Mbps, outputs: 0.00106049 Mbps (for a single frame)
# [info] Bandwidth of DDR buffers: 0.0 Mbps (for a single frame)
# [info] Bandwidth of inter context tensors: 0.0 Mbps (for a single frame)
# [info] Building HEF...
# [info] Successful Compilation (compilation time: 0s)

# %% [markdown]
# ### 1.1. Mostrar información sobre el modelo

# %%
# Guardar el HAR compilado

har_path = f"{model_name}_compiled_model_o{optimization_level}_c{compression_level}.har"
runner.save_har(har_path)
# Out:
# [info] Saved HAR to: /home/pablo/Documentos/Enxeñaría Informática/Cuarto/2º Cuatrimestre/Traballo Fin de Grao/hyper-rpi/results/models/model_ResBaGAN_discriminator_compiled_model_o2_c0.har

# %%
# Mostrar los modelos

# !hailo profiler {"../results/models/model_ResBaGAN_discriminator_compiled_model_o-100_c0.har"}
# !hailo profiler {"../results/models/model_ResBaGAN_discriminator_compiled_model_o0_c0.har"}
# !hailo profiler {"../results/models/model_ResBaGAN_discriminator_compiled_model_o1_c0.har"}
# !hailo profiler {"../results/models/model_ResBaGAN_discriminator_compiled_model_o2_c0.har"}
# Out:
# [info] Current Time: 19:07:37, 06/07/25
# [info] CPU: Architecture: , Model: , Number Of Cores: 16, Utilization: 2.6%
# [info] Memory: Total: 13GB, Available: 0GB
# [info] System info: OS: Linux, Kernel: 6.1.0-35-amd64
# [info] Hailo DFC Version: 3.31.0
# [info] HailoRT Version: 4.21.0
# [info] PCIe: No Hailo PCIe device was found
# [info] Running `hailo profiler ../results/models/model_ResBaGAN_discriminator_compiled_model_o0_c0.har`
# [info] Running profile for model_ResBaGAN_discriminator in state compiled_model
# [info]
# Model Details
# --------------------------------  ----------
# Input Tensors Shapes              32x32x5
# Operations per Input Tensor       0.04 GOPs
# Operations per Input Tensor       0.02 GMACs
# Pure Operations per Input Tensor  0.04 GOPs
# Pure Operations per Input Tensor  0.02 GMACs
# Model Parameters                  0.94 M
# --------------------------------  ----------
#
# Profiler Input Settings
# -----------------  -----------------
# Optimization Goal  Reach Highest FPS
# Profiler Mode      Compiled
# -----------------  -----------------
#
# Performance Summary
# ----------------------  --------------------
# Number of Devices       1
# Number of Contexts      1
# Throughput              22605.26 FPS
# Latency                 0.18 ms
# Operations per Second   1007.36 GOP/s
# MACs per Second         505.44 GMAC/s
# Total Input Bandwidth   110.38 Megabytes/sec
# Total Output Bandwidth  3.00 Megabytes/sec
# Context Switch Configs  N/A
# ----------------------  --------------------
# [info] Saved Profiler HTML Report to: /home/pablo/Documentos/Enxeñaría Informática/Cuarto/2º Cuatrimestre/Traballo Fin de Grao/hyper-rpi/notebooks/model_ResBaGAN_discriminator_compiled_model.html
